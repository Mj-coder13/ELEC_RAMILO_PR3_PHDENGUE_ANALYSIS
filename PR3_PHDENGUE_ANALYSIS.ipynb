# %% [markdown]
# <h2>ACTIVITY 3 - DENGUE ANALYSIS</h2>
# <HR>

# %% [markdown]
# <H4>ANALYST: MARK JAYSON D. RAMILO</H4>
# <HR>

# %% [markdown]
# <h2>1. IMPORT NECESSARY LIBRARIES</h2>
# <HR>

# %%
#import libraries
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# <H2>2. CONVERT DATASET TO DATAFRAME</H2>
# <HR>

# %%
dengue = pd.read_csv("C:\\Users\\DESIREE\\Downloads\\dengue.csv")
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %% [markdown]
# <H3>3.) CHECK DATAFRAME AND INFORMATION</H3>
# <hr>

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   object
#  1   Year           1020 non-null   int64
#  2   Region         1020 non-null   object
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 40.0+ KB

# %% [markdown]
# <H2>4.) CHECK BASIC DESCRIPTIVE STATISTICS</H2>
# <hr>

# %%
dengue.describe()
# Out:
#               Year  Dengue_Cases  Dengue_Deaths
# count  1020.000000   1020.000000    1020.000000
# mean   2018.000000   1124.926471      16.513725
# std       1.414907   1662.608878      96.358215
# min    2016.000000     10.000000       0.000000
# 25%    2017.000000    247.750000       1.000000
# 50%    2018.000000    582.500000       3.000000
# 75%    2019.000000   1284.250000       7.000000
# max    2020.000000  21658.000000    1651.000000

# %% [markdown]
# <h2>5.) CALL EACH COLUMN INDIVIDUALLY</h2>
# <hr>

# %%
dengue['Month']
# Out:
# 0         January
# 1        February
# 2           March
# 3           April
# 4             May
#           ...
# 1015       August
# 1016    September
# 1017      October
# 1018     November
# 1019     December
# Name: Month, Length: 1020, dtype: object

# %%
dengue['Year']
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1015    2020
# 1016    2020
# 1017    2020
# 1018    2020
# 1019    2020
# Name: Year, Length: 1020, dtype: int64

# %%
dengue['Region']
# Out:
# 0       Region I
# 1       Region I
# 2       Region I
# 3       Region I
# 4       Region I
#           ...
# 1015       BARMM
# 1016       BARMM
# 1017       BARMM
# 1018       BARMM
# 1019       BARMM
# Name: Region, Length: 1020, dtype: object

# %%
dengue['Dengue_Cases']
# Out:
# 0       705
# 1       374
# 2       276
# 3       240
# 4       243
#        ...
# 1015     91
# 1016     16
# 1017     13
# 1018     15
# 1019     23
# Name: Dengue_Cases, Length: 1020, dtype: int64

# %%
dengue['Dengue_Deaths']
# Out:
# 0       1
# 1       0
# 2       0
# 3       2
# 4       1
#        ..
# 1015    0
# 1016    8
# 1017    9
# 1018    1
# 1019    0
# Name: Dengue_Deaths, Length: 1020, dtype: int64

# %% [markdown]
# <h2>6.) CHECK FOR NULL VALUES</h2>
# <hr>

# %%
dengue.isnull().sum()
# Out:
# Month            0
# Year             0
# Region           0
# Dengue_Cases     0
# Dengue_Deaths    0
# dtype: int64

# %% [markdown]
# <h2>7.) CHECK COLUMN DATA TYPES</h2>
# <hr>

# %%
dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Month          1020 non-null   object
#  1   Year           1020 non-null   int64
#  2   Region         1020 non-null   object
#  3   Dengue_Cases   1020 non-null   int64
#  4   Dengue_Deaths  1020 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 40.0+ KB

# %% [markdown]
# <h2>8.) ADJUSTING DATA TYPES</h2>
# <hr>

# %%
dengue['Month'] = dengue ['Month'].astype('category')
dengue['Region'] = dengue ['Region'].astype('category')

# %%
dengue.dtypes
# Out:
# Month            category
# Year                int64
# Region           category
# Dengue_Cases        int64
# Dengue_Deaths       int64
# dtype: object

# %% [markdown]
# <H1> Data Visualization Using Seaborn:</H1>
# <H2> A comprehensive analysis with 5 questions and 2 insights each</H2>
# <hr>

# %% [markdown]
# <hr>
# <h2>Question 1: Which year recorded the highest number of dengue cases in the Philippines?</h2>
# <hr>

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=dengue, x='Year', y='Dengue_Cases', estimator='sum', palette='coolwarm')

plt.title("Total Dengue Cases per Year in the Philippines", fontsize=14, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Total Dengue Cases")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h2>Insight 1:</h2>
# <h4>As we can see in the graph, 2019 really stands out because it had the most dengue cases — over 400,000 in total, which is way higher than any other year.</h4>
# <HR>
# <h2>Insight 2:</h2>
# <h4>After 2019, the number of cases dropped a lot. This might be because of stronger awareness and better dengue prevention efforts after that big outbreak.</h4>
# <HR>

# %% [markdown]
# <h2>Question 2: Which regions have the most dengue deaths overall?</h2>
# <hr>

# %%
deaths_per_region = dengue.groupby("Region")["Dengue_Deaths"].sum().sort_values(ascending=True)

plt.figure(figsize=(10,6))
plt.barh(deaths_per_region.index, deaths_per_region.values, color='lightcoral')
plt.title("Total Dengue Deaths by Region", fontsize=14, fontweight='bold')
plt.xlabel("Total Dengue Deaths")
plt.ylabel("Region")
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.show()

deaths_per_region
# Out:
# Region
# Region IV-B     130
# Region I        157
# Region V        185
# Region II       193
# BARMM           332
# Region XI       385
# Region III      482
# Region IX       532
# Region VIII     585
# Region IV-A     652
# Region X        848
# Region XIII     966
# CAR            1008
# Region VII     1760
# Region VI      1825
# Region XII     2796
# NCR            4008
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 3:</h2>
# <h4>If we take a look at the chart, The National Capital Region (NCR) really stands out since it has the most dengue deaths among all regions. It’s followed by Region XII and Region VI, which also have big populations.</h4>
# <hr>
# <h2>Insight 4:</h2>
# <h4>And the lowest numbers came from Region IV-B and Region I, suggesting that the region may have more effective dengue prevention measures, lower population density, or fewer mosquito breeding sites compared to other regions.</h4>
# <hr>

# %% [markdown]
# <h2>Question 3: What months show the highest average dengue cases across all years?</h2>
# <hr>

# %%
avg_month = dengue.groupby("Month")["Dengue_Cases"].mean().reindex([
    "January","February","March","April","May","June",
    "July","August","September","October","November","December"])

plt.figure(figsize=(12,6))
sns.lineplot(x=avg_month.index, y=avg_month.values, marker='o', color='teal')
plt.title("Average Monthly Dengue Cases (All Years)", fontsize=14, fontweight='bold')
plt.xlabel("Month")
plt.ylabel("Average Dengue Cases")
plt.xticks(rotation=30)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Insight 5:</h2>
# <h4>The line started to rise after the months of May to August, and August being the highest and I think the reason is that it may be mostly the rainy season, so there is more water and this has caused the increase in mosquitoes.</h4>
# <hr>
# <h2>Insight 6:</h2>
# <h4>And based on the graph, April and May have the lowest averages, and they’re almost the same. Maybe because those months are usually hot and dry, so mosquitoes don’t multiply that much, that’s why there are fewer dengue cases.</h4>
# <hr>

# %% [markdown]
# <h2>Question 4: What trends can be observed between dengue cases and deaths per year?</h2>
# <hr>

# %%
yearly_data = dengue.groupby("Year")[["Dengue_Cases", "Dengue_Deaths"]].sum()
normalized = yearly_data / yearly_data.max()

plt.figure(figsize=(12,6))
sns.heatmap(normalized, annot=yearly_data, fmt=".0f", cmap="YlOrRd")
plt.title("Yearly Trends of Dengue Cases and Dengue Deaths", fontsize=14, fontweight='bold')
plt.xlabel("Data Type", fontsize=12)
plt.ylabel("Year", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Insight 7:</h2>
# <h4>From the heatmap, it’s clear that years with more dengue cases don’t always have more deaths. For example, 2019 had the highest number of cases, but 2016 had the most deaths.</h4>
# <hr>
# <h2>Insight 8:</h2>
# <h4>This shows that having more cases doesn’t always mean more people will die, which might mean that healthcare responses and early treatments got better in the later years.</h4>
# <hr>

# %% [markdown]
# <h2>Question 5: How has the number of dengue deaths changed over time per region?</h2>
# <hr>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=dengue, x='Year', y='Dengue_Deaths', hue='Region', s=100, palette='Set1')

plt.title("Dengue Deaths Over Time by Region", fontsize=14, fontweight='bold')
plt.xlabel("Year")
plt.ylabel("Number of Dengue Deaths")
plt.xticks(dengue['Year'].unique())
plt.grid(True, linestyle='-')
plt.show()

dengue.groupby('Year')['Dengue_Deaths'].sum().sort_values(ascending=False)
# Out:
# Year
# 2016    8127
# 2017    4563
# 2019    1733
# 2018    1226
# 2020    1195
# Name: Dengue_Deaths, dtype: int64

# %% [markdown]
# <h2>Insight 9:</h2>
# <hr>
# <h4>By looking at the scatterplot, it shows that the total number of dengue deaths decreases from 2016 to 2020, starting at 8127 deaths and falling to 1195 deaths. This downward trend is visible across almost all regions, suggesting a general improvement in dengue control over the years. Despite the overall decline, the visual emphasizes the importance of continuing preventive measures to maintain this positive trend.</h4>
# <hr>
# <h2>Insight 10:</h2>
# <h4>Overall, dengue deaths have been decreasing over the years. However, some regions continue to report higher deaths than others. Even in years when overall deaths are lower, these regions can still have high numbers, showing that they are more affected by dengue. This also suggests that local outbreaks may happen because of factors like weather, mosquito abundance, or population vulnerability.</h4>
# <hr>
